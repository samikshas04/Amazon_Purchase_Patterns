# %%
import pandas as pd 
import numpy as np
import seaborn as sb 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Datasets/Amazon_Dataset.csv")

# %%
df
# Out:
#            Name   BirthDate MaritalStatus Gender  \
# 0         Wyatt  1983-04-28             M      M
# 1       Shannon  1948-06-26             S      F
# 2      Clarence  1948-10-09             S      M
# 3          Luke  1982-03-07             S      M
# 4        Jordan  1982-09-20             S      M
# ...         ...         ...           ...    ...
# 18463     Tommy  1962-07-04             M      M
# 18464      Nina  1964-11-10             S      F
# 18465      Ivan  1964-01-05             S      M
# 18466   Clayton  1963-03-05             M      M
# 18467     Jésus  1963-12-08             M      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
df.dtypes
# Out:
# Name               object
# BirthDate          object
# MaritalStatus      object
# Gender             object
# EmailAddress       object
# YearlyIncome        int64
# Region             object
# City               object
# State-Province     object
# CategoryName       object
# ItemCost          float64
# NumberofItem        int64
# dtype: object

# %%
df.Name.value_counts()
# Out:
# Name
# Katherine    97
# Marcus       97
# Richard      94
# Lucas        93
# Dalton       93
#              ..
# Masaki        1
# Birgit        1
# Ramón         1
# Mike          1
# Jeff          1
# Name: count, Length: 669, dtype: int64

# %%
df.Name.nunique()
# Out:
# 669

# %%
df.Name.unique()
# Out:
# array(['Wyatt', 'Shannon', 'Clarence', 'Luke', 'Jordan', 'Destiny',
#        'Ethan', 'Seth', 'Russell', 'Alejandro', 'Harold', 'Jessie',
#        'Jill', 'Jimmy', 'Bethany', 'Theresa', 'Denise', 'Jaime', 'Ebony',
#        'Wendy', 'Jennifer', 'Chloe', 'Diana', 'Marc', 'Jesse', 'Amanda',
#        'Megan', 'Nathan', 'Adam', 'Leonard', 'Christine', 'Jaclyn',
#        'Jeremy', 'Carol', 'Alan', 'Daniel', 'Heidi', 'Ana', 'Deanna',
#        'Gilbert', 'Michele', 'Carl', 'Ashlee', 'Jon', 'Todd', 'Noah',
#        'Angela', 'Chase', 'Jessica', 'Grace', 'Caleb', 'Tiffany',
#        'Carolyn', 'Willie', 'Linda', 'Casey', 'Amy', 'Levi', 'Felicia',
#        'Blake', 'Leah', 'Gina', 'Donald', 'Damien', 'Savannah', 'Alyssa',
#        'Lucas', 'Emily', 'Ryan', 'Tamara', 'Hunter', 'Abigail', 'Trevor',
#        'Dalton', 'Cheryl', 'Aimee', 'Cedric', 'Chad', 'Andrés', 'Edwin',
#        'Mallory', 'Latasha', 'Abby', 'Julia', 'Cassie', 'Edgar',
# ...

# %%
df.groupby ('Name')['BirthDate']

# %%
df.describe()
# Out:
#         YearlyIncome      ItemCost  NumberofItem
# count   18468.000000  18468.000000  18468.000000
# mean    57293.155729    898.636953     50.155891
# std     32292.579356   1233.956478     28.885948
# min     10000.000000      2.290000      1.000000
# 25%     30000.000000      8.990000     25.000000
# 50%     60000.000000     35.000000     50.000000
# 75%     70000.000000   2071.419600     75.000000
# max    170000.000000   3578.270000    100.000000

# %%
df.isnull().sum()
# Out:
# Name                  0
# BirthDate             0
# MaritalStatus         0
# Gender                1
# EmailAddress          1
# YearlyIncome          0
# Region                0
# City                  0
# State-Province        0
# CategoryName      18071
# ItemCost              0
# NumberofItem          0
# dtype: int64

# %%
 df = df.drop('CategoryName',axis=1)

# %%
df
# Out:
#            Name   BirthDate MaritalStatus Gender  \
# 0         Wyatt  1983-04-28             M      M
# 1       Shannon  1948-06-26             S      F
# 2      Clarence  1948-10-09             S      M
# 3          Luke  1982-03-07             S      M
# 4        Jordan  1982-09-20             S      M
# ...         ...         ...           ...    ...
# 18463     Tommy  1962-07-04             M      M
# 18464      Nina  1964-11-10             S      F
# 18465      Ivan  1964-01-05             S      M
# 18466   Clayton  1963-03-05             M      M
# 18467     Jésus  1963-12-08             M      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
o =df[['Name','BirthDate','EmailAddress']]

# %%
o
# Out:
#            Name   BirthDate                    EmailAddress
# 0         Wyatt  1983-04-28     wyatt32@adventure-works.com
# 1       Shannon  1948-06-26    shannon1@adventure-works.com
# 2      Clarence  1948-10-09  clarence32@adventure-works.com
# 3          Luke  1982-03-07      luke18@adventure-works.com
# 4        Jordan  1982-09-20    jordan73@adventure-works.com
# ...         ...         ...                             ...
# 18463     Tommy  1962-07-04      tommy2@adventure-works.com
# 18464      Nina  1964-11-10      nina21@adventure-works.com
# 18465      Ivan  1964-01-05       ivan0@adventure-works.com
# 18466   Clayton  1963-03-05    clayton0@adventure-works.com
# 18467     Jésus  1963-12-08      jésus9@adventure-works.com
#
# [18468 rows x 3 columns]

# %%
bottom = df.tail(20)

# %%
bottom
# Out:
#              Name   BirthDate MaritalStatus Gender  \
# 18448      Eugene  1981-09-05             S      M
# 18449         Roy  1981-06-19             S      M
# 18450       Lance  1947-11-26             M      M
# 18451      Monica  1965-10-16             M      F
# 18452  Jacqueline  1965-06-27             M      F
# 18453   Dominique  1965-04-26             M      F
# 18454      Nathan  1964-08-25             S      M
# 18455        Dana  1964-03-26             S      F
# 18456       Lacey  1964-03-14             M      F
# 18457      Carmen  1964-05-22             S      F
# 18458       Jaime  1963-10-04             M      M
# 18459       Jared  1963-09-23             S      M
# 18460   Elizabeth  1963-07-03             M      F
# 18461        Neil  1963-07-06             M      M
# 18462      Darren  1963-05-25             S      M
# 18463       Tommy  1962-07-04             M      M
# 18464        Nina  1964-11-10             S      F
# ...

# %%
df.BirthDate = df.BirthDate.astype('datetime64[ns]')
df
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 0         Wyatt 1983-04-28             M      M
# 1       Shannon 1948-06-26             S      F
# 2      Clarence 1948-10-09             S      M
# 3          Luke 1982-03-07             S      M
# 4        Jordan 1982-09-20             S      M
# ...         ...        ...           ...    ...
# 18463     Tommy 1962-07-04             M      M
# 18464      Nina 1964-11-10             S      F
# 18465      Ivan 1964-01-05             S      M
# 18466   Clayton 1963-03-05             M      M
# 18467     Jésus 1963-12-08             M      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
df.Gender=df.Gender.fillna('Unknown')
df.EmailAddress=df.EmailAddress.fillna('Unknown')

# %%
df
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 0         Wyatt 1983-04-28             M      M
# 1       Shannon 1948-06-26             S      F
# 2      Clarence 1948-10-09             S      M
# 3          Luke 1982-03-07             S      M
# 4        Jordan 1982-09-20             S      M
# ...         ...        ...           ...    ...
# 18463     Tommy 1962-07-04             M      M
# 18464      Nina 1964-11-10             S      F
# 18465      Ivan 1964-01-05             S      M
# 18466   Clayton 1963-03-05             M      M
# 18467     Jésus 1963-12-08             M      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
df.Region.unique()
# Out:
# array(['South', 'East', 'Central', 'West', 'North'], dtype=object)

# %%
df.City.unique()
# Out:
# array(['Imperial Beach', 'Sunbury', 'Bendigo', 'Langley', 'Metchosin',
#        'Beaverton', 'Bellingham', 'Bellflower', 'Concord', 'Hawthorne',
#        'Goulburn', 'Warrnambool', 'St. Leonards', 'Cloverdale',
#        'Matraville', 'Melbourne', 'Milsons Point', 'North Sydney',
#        'Cranbourne', 'National City', 'Cliffside', 'Lavender Bay',
#        'Wollongong', 'Tacoma', 'Glendale', 'Los Angeles', 'Hervey Bay',
#        'Geelong', 'Chula Vista', 'Hobart', 'Caloundra', 'San Diego',
#        'East Brisbane', 'Newcastle', 'Lane Cove', 'Findon', 'Townsville',
#        'Gold Coast', 'Portland', 'Redmond', 'Downey', 'La Jolla',
#        'Lebanon', 'Port Orchard', 'Springwood', 'Melton', 'Perth',
#        'Fremont', 'Lincoln Acres', 'Newport Beach', 'Santa Monica',
#        'Long Beach', 'Haney', 'Port Macquarie', 'Rhodes', 'Sydney',
#        'Darlinghurst', 'South Melbourne', 'Seaford', 'North Ryde',
#        'San Gabriel', 'Renton', 'Sedro Woolley', 'Langford',
# ...

# %%
df['State-Province'].unique()
# Out:
# array(['California', 'Victoria', 'British Columbia', 'Oregon',
#        'Washington', 'Queensland', 'New South Wales', 'South Australia',
#        'Tasmania', 'Nordrhein-Westfalen', 'England', 'Essonne', 'Yveline',
#        'Hessen', 'Hamburg', 'Seine Saint Denis', 'Saarland', 'Bayern',
#        'Seine (Paris)', 'Pas de Calais', 'Moselle', 'Hauts de Seine',
#        'Nord', 'Seine et Marne', 'Loir et Cher', 'Loiret',
#        'Charente-Maritime', 'Brandenburg', 'Alabama', "Val d'Oise",
#        'Val de Marne', 'Minnesota', 'Wyoming', 'Ohio', 'Garonne (Haute)',
#        'Kentucky', 'New York', 'Texas', 'Missouri', 'Somme', 'Alberta',
#        'Georgia', 'Florida', 'Illinois', 'South Carolina',
#        'North Carolina', 'Virginia', 'Ontario', 'Mississippi', 'Montana',
#        'Arizona', 'Massachusetts', 'Utah'], dtype=object)

# %%
df.Region.value_counts()
# Out:
# Region
# East       6921
# South      6920
# West       4616
# North         9
# Central       2
# Name: count, dtype: int64

# %%
df.columns = df.columns.str.replace("-",'')
df
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 0         Wyatt 1983-04-28             M      M
# 1       Shannon 1948-06-26             S      F
# 2      Clarence 1948-10-09             S      M
# 3          Luke 1982-03-07             S      M
# 4        Jordan 1982-09-20             S      M
# ...         ...        ...           ...    ...
# 18463     Tommy 1962-07-04             M      M
# 18464      Nina 1964-11-10             S      F
# 18465      Ivan 1964-01-05             S      M
# 18466   Clayton 1963-03-05             M      M
# 18467     Jésus 1963-12-08             M      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
df.MaritalStatus= df.MaritalStatus.replace('[M]',"Marrired",regex=True)
df.MaritalStatus= df.MaritalStatus.replace('[S]',"Single",regex=True)

# %%
df
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 0         Wyatt 1983-04-28      Marrired      M
# 1       Shannon 1948-06-26        Single      F
# 2      Clarence 1948-10-09        Single      M
# 3          Luke 1982-03-07        Single      M
# 4        Jordan 1982-09-20        Single      M
# ...         ...        ...           ...    ...
# 18463     Tommy 1962-07-04      Marrired      M
# 18464      Nina 1964-11-10        Single      F
# 18465      Ivan 1964-01-05        Single      M
# 18466   Clayton 1963-03-05      Marrired      M
# 18467     Jésus 1963-12-08      Marrired      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
df[(df.Region == 'Central') & (df.YearlyIncome >50000)]
# Out:
#       Name  BirthDate MaritalStatus Gender                  EmailAddress  \
# 8  Russell 1982-09-17      Marrired      M  russell7@adventure-works.com
#
#    YearlyIncome   Region     City StateProvince  ItemCost  NumberofItem
# 8         60000  Central  Concord    California   3399.99            45

# %%
c = df[df.StateProvince == 'California']

# %%
c
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 0         Wyatt 1983-04-28      Marrired      M
# 7          Seth 1982-10-11      Marrired      M
# 8       Russell 1982-09-17      Marrired      M
# 20     Jennifer 1982-12-18      Marrired      F
# 25       Amanda 1981-10-16      Marrired      F
# ...         ...        ...           ...    ...
# 18310  Victoria 1984-02-17        Single      F
# 18312     Jason 1983-10-13      Marrired      M
# 18331  Jonathan 1969-08-15      Marrired      M
# 18334     Julia 1969-11-09        Single      F
# 18336     Lydia 1969-08-11        Single      F
#
#                          EmailAddress  YearlyIncome   Region            City  \
# 0         wyatt32@adventure-works.com         30000    South  Imperial Beach
# 7          seth46@adventure-works.com         40000     West      Bellflower
# 8        russell7@adventure-works.com         60000  Central         Concord
# ...

# %%
df.describe(include='all')
# Out:
#              Name                      BirthDate MaritalStatus Gender  \
# count       18468                          18468         18468  18468
# unique        669                            NaN             2      3
# top     Katherine                            NaN      Marrired      M
# freq           97                            NaN         10005   9342
# mean          NaN  1966-01-26 07:50:15.204678352           NaN    NaN
# min           NaN            1914-08-13 00:00:00           NaN    NaN
# 25%           NaN            1958-09-06 00:00:00           NaN    NaN
# 50%           NaN            1967-08-11 00:00:00           NaN    NaN
# 75%           NaN            1974-09-26 06:00:00           NaN    NaN
# max           NaN            1984-12-26 00:00:00           NaN    NaN
# std           NaN                            NaN           NaN    NaN
#
#                        EmailAddress   YearlyIncome Region    City  \
# ...

# %%
df[df['StateProvince'] == 'Ohio']
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 716       Erick 1963-02-08      Marrired      M
# 1940   Marshall 1966-03-11        Single      M
# 10233     Alvin 1981-03-18        Single      M
# 16024      Paul 1961-06-06      Marrired      M
#
#                          EmailAddress  YearlyIncome Region        City  \
# 716       erick20@adventure-works.com         60000   East  Cincinnati
# 1940   marshall12@adventure-works.com         70000   East  Cincinnati
# 10233     alvin27@adventure-works.com         40000   East    Columbus
# 16024       paul5@adventure-works.com         20000  South     Burbank
#
#       StateProvince  ItemCost  NumberofItem
# 716            Ohio   3578.27            72
# 1940           Ohio   3578.27             1
# 10233          Ohio     54.99            94
# 16024          Ohio     35.00            94

# %%
df[df['StateProvince'] == 'Utah']
# Out:
#           Name  BirthDate MaritalStatus Gender                  EmailAddress  \
# 17790  Randall 1977-11-19        Single      M  randall5@adventure-works.com
# 17843    Micah 1970-10-09        Single      M    micah9@adventure-works.com
#
#        YearlyIncome Region        City StateProvince  ItemCost  NumberofItem
# 17790         40000  South  Cedar City          Utah      2.29            23
# 17843         80000   West   Bountiful          Utah      4.99            23

# %%
#df[df['CategoryName'] == 'Bikes']

# %%
#df[df['CategoryName'] == 'Components']

# %%
df['sales'] = df['NumberofItem'] * df['ItemCost']

# %%
df
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 0         Wyatt 1983-04-28      Marrired      M
# 1       Shannon 1948-06-26        Single      F
# 2      Clarence 1948-10-09        Single      M
# 3          Luke 1982-03-07        Single      M
# 4        Jordan 1982-09-20        Single      M
# ...         ...        ...           ...    ...
# 18463     Tommy 1962-07-04      Marrired      M
# 18464      Nina 1964-11-10        Single      F
# 18465      Ivan 1964-01-05        Single      M
# 18466   Clayton 1963-03-05      Marrired      M
# 18467     Jésus 1963-12-08      Marrired      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
income = df.groupby('StateProvince')['YearlyIncome'].mean().nlargest(10).reset_index()

# %%
income
# Out:
#      StateProvince   YearlyIncome
# 0   South Carolina  110000.000000
# 1          Montana   90000.000000
# 2        Minnesota   80000.000000
# 3         Missouri   80000.000000
# 4         Kentucky   70000.000000
# 5          Georgia   66666.666667
# 6       California   66592.392528
# 7  New South Wales   64742.930591
# 8       Queensland   64670.050761
# 9         Tasmania   64476.190476

# %%
df.groupby(['Gender', 'StateProvince']).size().reset_index()
# Out:
#      Gender    StateProvince     0
# 0         F          Alabama     1
# 1         F          Alberta     5
# 2         F          Arizona     1
# 3         F           Bayern   114
# 4         F      Brandenburg    14
# ..      ...              ...   ...
# 89        M         Virginia     1
# 90        M       Washington  1146
# 91        M          Wyoming     1
# 92        M          Yveline    89
# 93  Unknown  New South Wales     1
#
# [94 rows x 3 columns]

# %%
pd.crosstab(index=df.Gender,columns=df.StateProvince,margins=True)
# Out:
# StateProvince  Alabama  Alberta  Arizona  Bayern  Brandenburg  \
# Gender
# F                    1        5        1     114           14
# M                    0        6        1     114           16
# Unknown              0        0        0       0            0
# All                  1       11        2     228           30
#
# StateProvince  British Columbia  California  Charente-Maritime  England  \
# Gender
# F                           761        2205                  7      934
# M                           798        2238                 14      979
# Unknown                       0           0                  0        0
# All                        1559        4443                 21     1913
#
# StateProvince  Essonne  ...  Texas  Utah  Val d'Oise  Val de Marne  Victoria  \
# Gender                  ...
# F                   83  ...      3     0          17            15       414
# M                   67  ...      1     2          13            15       477
# ...

# %%
cus = df.groupby(['Region', 'MaritalStatus']).size().reset_index()

# %%
cus
# Out:
#     Region MaritalStatus     0
# 0  Central      Marrired     1
# 1  Central        Single     1
# 2     East      Marrired  3743
# 3     East        Single  3178
# 4    North      Marrired     1
# 5    North        Single     8
# 6    South      Marrired  3777
# 7    South        Single  3143
# 8     West      Marrired  2483
# 9     West        Single  2133

# %%
min = df.groupby(['Region', 'Gender'])['NumberofItem'].min().nlargest().reset_index()

# %%
min
# Out:
#     Region   Gender  NumberofItem
# 0     East  Unknown            92
# 1  Central        M            45
# 2    North        M            19
# 3    North        F             5
# 4     East        F             1

# %%
TOTsales = df.groupby(['Gender', 'MaritalStatus'])['sales'].sum().reset_index()

# %%
TOTsales
# Out:
#     Gender MaritalStatus         sales
# 0        F      Marrired  2.177250e+08
# 1        F        Single  2.036068e+08
# 2        M      Marrired  2.464850e+08
# 3        M        Single  1.724245e+08
# 4  Unknown      Marrired  3.292008e+05
